# %%
#import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#data on boarding
from google.colab import files
df = files.upload()
# Out:
#      <input type="file" id="files-0130ab6c-039b-4a48-8dad-972505cfc4d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0130ab6c-039b-4a48-8dad-972505cfc4d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#raw data into data frame
df = pd.read_csv('01Exercise1.csv')

# %%
df_copy=df.copy()#shallow copy

# %%
df_copy
# Out:
#      gender married   ch  income  loanamt status
# 0         1      No  1.0    5849      NaN      Y
# 1         1     Yes  1.0    4583    128.0      N
# 2         1     Yes  1.0    3000     66.0      Y
# 3         1     Yes  1.0    2583    120.0      Y
# 4         1      No  1.0    6000    141.0      Y
# ..      ...     ...  ...     ...      ...    ...
# 609       0      No  1.0    2900     71.0      Y
# 610       1     Yes  1.0    4106     40.0      Y
# 611       1     Yes  1.0    8072    253.0      Y
# 612       1     Yes  1.0    7583    187.0      Y
# 613       0      No  0.0    4583    133.0      N
#
# [614 rows x 6 columns]

# %%
df
# Out:
#      gender married   ch  income  loanamt status
# 0      Male      No  1.0    5849      NaN      Y
# 1      Male     Yes  1.0    4583    128.0      N
# 2      Male     Yes  1.0    3000     66.0      Y
# 3      Male     Yes  1.0    2583    120.0      Y
# 4      Male      No  1.0    6000    141.0      Y
# ..      ...     ...  ...     ...      ...    ...
# 609  Female      No  1.0    2900     71.0      Y
# 610    Male     Yes  1.0    4106     40.0      Y
# 611    Male     Yes  1.0    8072    253.0      Y
# 612    Male     Yes  1.0    7583    187.0      Y
# 613  Female      No  0.0    4583    133.0      N
#
# [614 rows x 6 columns]

# %%
df.head()
# Out:
#   gender married   ch  income  loanamt status
# 0   Male      No  1.0    5849      NaN      Y
# 1   Male     Yes  1.0    4583    128.0      N
# 2   Male     Yes  1.0    3000     66.0      Y
# 3   Male     Yes  1.0    2583    120.0      Y
# 4   Male      No  1.0    6000    141.0      Y

# %%
df.shape
# Out:
# (614, 6)

# %%
df.tail()
# Out:
#      gender married   ch  income  loanamt status
# 609  Female      No  1.0    2900     71.0      Y
# 610    Male     Yes  1.0    4106     40.0      Y
# 611    Male     Yes  1.0    8072    253.0      Y
# 612    Male     Yes  1.0    7583    187.0      Y
# 613  Female      No  0.0    4583    133.0      N

# %%
df.describe()#mini statistical report
# Out:
#                ch        income     loanamt
# count  564.000000    614.000000  592.000000
# mean     0.842199   5403.459283  146.412162
# std      0.364878   6109.041673   85.587325
# min      0.000000    150.000000    9.000000
# 25%      1.000000   2877.500000  100.000000
# 50%      1.000000   3812.500000  128.000000
# 75%      1.000000   5795.000000  168.000000
# max      1.000000  81000.000000  700.000000

# %%
df.isnull()
# Out:
#      gender  married     ch  income  loanamt  status
# 0     False    False  False   False     True   False
# 1     False    False  False   False    False   False
# 2     False    False  False   False    False   False
# 3     False    False  False   False    False   False
# 4     False    False  False   False    False   False
# ..      ...      ...    ...     ...      ...     ...
# 609   False    False  False   False    False   False
# 610   False    False  False   False    False   False
# 611   False    False  False   False    False   False
# 612   False    False  False   False    False   False
# 613   False    False  False   False    False   False
#
# [614 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# gender     13
# married     3
# ch         50
# income      0
# loanamt    22
# status      0
# dtype: int64

# %% [markdown]
# Dealing with the missing values:
#
# Gender = ((13/614)*100)= 2.11
#
# married = ((3/614)*100)=  0.48
#
# ch = ((50/614*100))= 8.14
#
# loanamt = ((22/614*100)) = 3.58

# %%
# Replace Missing Values. Drop the rows.
dfs = dfs.dropna()

# %%
# Drop irrelevant columns based on business sense
dfs = dfs.drop(['gender'], axis=1)

# %%
# Create Dummy variables
dfs.dtypes
dfs = pd.get_dummies(dfs, drop_first=True)

# %%
dfs
# Out:
#       ch  income  loanamt  married_Yes  status_Y
# 1    1.0    4583    128.0            1         0
# 2    1.0    3000     66.0            1         1
# 3    1.0    2583    120.0            1         1
# 4    1.0    6000    141.0            0         1
# 5    1.0    5417    267.0            1         1
# ..   ...     ...      ...          ...       ...
# 609  1.0    2900     71.0            0         1
# 610  1.0    4106     40.0            1         1
# 611  1.0    8072    253.0            1         1
# 612  1.0    7583    187.0            1         1
# 613  0.0    4583    133.0            0         0
#
# [543 rows x 5 columns]

# %%
x = df.iloc[:,:-1]

# %%
x
# Out:
#      gender married   ch  income  loanamt
# 0         1      No  1.0    5849      NaN
# 1         1     Yes  1.0    4583    128.0
# 2         1     Yes  1.0    3000     66.0
# 3         1     Yes  1.0    2583    120.0
# 4         1      No  1.0    6000    141.0
# ..      ...     ...  ...     ...      ...
# 609       0      No  1.0    2900     71.0
# 610       1     Yes  1.0    4106     40.0
# 611       1     Yes  1.0    8072    253.0
# 612       1     Yes  1.0    7583    187.0
# 613       0      No  0.0    4583    133.0
#
# [614 rows x 5 columns]

# %%
y = df.iloc[:, -1]

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: status, Length: 614, dtype: object

# %%
# Normalize the data (Income and Loan Amount) Using StandardScaler
from sklearn.preprocessing import StandardScaler
scalar_ = StandardScaler()

# %%
dfs['income'] = scalar_.fit_transform(dfs[['income']])
dfs['loanamt'] = scalar_.fit_transform(dfs[['loanamt']])

# %%
#Create the x (Independent) and y (Dependent) dataframes
y = dfs[['status_Y']]
x = dfs.drop(['status_Y'], axis=1)

# %%
# Split the X and Y dataset into training and testing set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = \
train_test_split(x, y, test_size = 0.3, random_state = 1234, stratify=y)

# %%
# Import and build Support Vector Classifier
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
# Predict the outcome using Test data
y_predict = svc.predict(x_test)

# %%
# Build the conufsion matrix and get the accuracy/score
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predict)

# %%
cm
# Out:
# array([[ 20,  31],
#        [  0, 112]])

# %%
score = svc.score(x_test,y_test)

# %%
score
# Out:
# 0.8098159509202454
